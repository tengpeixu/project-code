# %%
from ultralytics import YOLO

# Load a model
#model = YOLO('yolov8n.yaml')  # build a new model from YAML
model = YOLO('yolov8n.pt')  # 指定本地路径，不然会下载模型
 
# Train the model
model.train(data='coco_paper.yaml', epochs=1000, imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.0.227 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.200  Python-3.11.0 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %%
from ultralytics import YOLO

# 加载训练好的模型开启预测
model = YOLO("runs/detect/train3/weights/best.pt") 
model.info()
# Out:
# Model summary: 225 layers, 3011433 parameters, 0 gradients, 8.2 GFLOPs
# (225, 3011433, 0, 8.1963008)

# %%
result = model.predict(source=r"D:\Code\paper-detection-master\test\paper (1)_1091.png",save_txt=True, imgsz=416, save_conf=True, save=True)
# Out:
# image 1/1 D:\Code\paper-detection-master\test\paper (1)_1091.png: 416x352 1 Formula, 1 DataGraph, 78.4ms
# Speed: 3.0ms preprocess, 78.4ms inference, 3.2ms postprocess per image at shape (1, 3, 416, 352)
# Results saved to runs\detect\predict
# 1 label saved to runs\detect\predict\labels

# %%
# result = model.predict(source="other_image\paper (1)_102.png",save_txt=True, imgsz=416, save_conf=True, save=True)

# %%
import glob
import os
import cv2

file_path = "test/"  # 文件夹路径
images_path = glob.glob(os.path.join(file_path + '*.png'))  # 所有图片路径

for image_path in images_path:
    # image_path 为
    # image = cv2.imread(image_path)
    result = model.predict(source=image_path, 
                           save_txt=True, imgsz=416, 
                           save_conf=True, save=True)
# Out:
# image 1/1 d:\Code\paper-detection-master\test\paper (1)_1001.png: 416x352 2 Formulas, 82.9ms
# Speed: 4.1ms preprocess, 82.9ms inference, 4.0ms postprocess per image at shape (1, 3, 416, 352)
# Results saved to runs\detect\predict
# 2 labels saved to runs\detect\predict\labels
#
# image 1/1 d:\Code\paper-detection-master\test\paper (1)_1002.png: 416x352 5 Formulas, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 13.0ms postprocess per image at shape (1, 3, 416, 352)
# Results saved to runs\detect\predict
# 3 labels saved to runs\detect\predict\labels
#
# image 1/1 d:\Code\paper-detection-master\test\paper (1)_1003.png: 416x352 4 Formulas, 2 DataGraphs, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 352)
# Results saved to runs\detect\predict
# 4 labels saved to runs\detect\predict\labels
#
# image 1/1 d:\Code\paper-detection-master\test\paper (1)_1004.png: 416x352 2 Formulas, 2 DataGraphs, 4.6ms
# ...

# %%
import glob
import os
import cv2

file_path = "test2/"  # 文件夹路径
images_path = glob.glob(os.path.join(file_path + '*.png'))  # 所有图片路径

for image_path in images_path:
    # image_path 为
    # image = cv2.imread(image_path)
    result = model.predict(source=image_path, 
                           save_txt=True, imgsz=416, 
                           save_conf=True, save=True)
# Out:
# image 1/1 d:\Code\paper-detection-master\test2\_00.png: 416x320 2 Formulas, 104.5ms
# Speed: 3.0ms preprocess, 104.5ms inference, 110.5ms postprocess per image at shape (1, 3, 416, 320)
# Results saved to runs\detect\predict2
# 1 label saved to runs\detect\predict2\labels
#
# image 1/1 d:\Code\paper-detection-master\test2\_01.png: 416x320 1 SketchMap, 6.0ms
# Speed: 2.5ms preprocess, 6.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 320)
# Results saved to runs\detect\predict2
# 2 labels saved to runs\detect\predict2\labels
#
# image 1/1 d:\Code\paper-detection-master\test2\_02.png: 416x320 6 Formulas, 1 SketchMap, 6.0ms
# Speed: 1.0ms preprocess, 6.0ms inference, 4.0ms postprocess per image at shape (1, 3, 416, 320)
# Results saved to runs\detect\predict2
# 3 labels saved to runs\detect\predict2\labels
#
# image 1/1 d:\Code\paper-detection-master\test2\_03.png: 416x320 5 Formulas, 6.0ms
# ...

# %%
# import cv2
# annotated_frame = result[0].plot()
# # Display the annotated frame
# cv2.namedWindow('window', cv2.WINDOW_FREERATIO)
# cv2.imshow("window", annotated_frame)
# cv2.waitKey()
# cv2.destroyAllWindows()
